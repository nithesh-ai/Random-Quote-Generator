# %% [markdown]
# <a href="https://colab.research.google.com/github/nithesh-ai/Random-Quote-Generator/blob/main/Rock_Vs_Mine_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# Data Collection and Preprocessing

# %%
#loading the dataset to pandas dataframe
sonar_data = pd.read_csv('/content/ sonar data.csv',header=None)

# %%
sonar_data.head()
#no of rows and columns
sonar_data.shape
sonar_data.describe() #describes ---> gives some statistical data
sonar_data[60].value_counts() # no of rock and mines
sonar_data.groupby(60).mean()  # calculate mean
# Out:
#           0         1         2         3   ...        56        57        58        59
# 60                                          ...
# M   0.034989  0.045544  0.050720  0.064768  ...  0.007825  0.009060  0.008695  0.006930
# R   0.022498  0.030303  0.035951  0.041447  ...  0.007814  0.006677  0.007078  0.006024
#
# [2 rows x 60 columns]

# %% [markdown]
# Separating data and columns

# %%
X=sonar_data.drop(columns=60 ,axis =1)
Y=sonar_data[60]
print(X)
print(Y)
# Out:
#          0       1       2       3       4       5   ...      54      55      56      57      58      59
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  ...  0.0072  0.0167  0.0180  0.0084  0.0090  0.0032
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  ...  0.0094  0.0191  0.0140  0.0049  0.0052  0.0044
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  ...  0.0180  0.0244  0.0316  0.0164  0.0095  0.0078
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  ...  0.0085  0.0073  0.0050  0.0044  0.0040  0.0117
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  ...  0.0110  0.0015  0.0072  0.0048  0.0107  0.0094
# ..      ...     ...     ...     ...     ...     ...  ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  ...  0.0033  0.0101  0.0065  0.0115  0.0193  0.0157
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  ...  0.0063  0.0063  0.0034  0.0032  0.0062  0.0067
# ...

# %% [markdown]
# Splitting into Train and Test Data

# %%
X_train ,X_test ,Y_train,Y_test = train_test_split(X,Y,test_size=0.1,stratify= Y ,random_state=1)
print(X.shape ,X_train.shape,X_test.shape)
# Out:
# (208, 60) (187, 60) (21, 60)

# %% [markdown]
# Training the Model ----> Logistic Regression

# %%
model = LogisticRegression()

# %%
#training the data with logistic regression
model.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Model Evaluation

# %%
#check accuracy of the model on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction,Y_train)
print("accuracy on training data is ---" ,training_data_accuracy)
# Out:
# accuracy on training data is --- 0.8342245989304813

# %%
#accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction,Y_test)
print("accuracy on test data is ---" ,test_data_accuracy)
# Out:
# accuracy on test data is --- 0.7619047619047619

# %% [markdown]
# Making a Predictive System

# %%
input_data =(0.0530,0.0885,0.1997,0.2604,0.3225,0.2247,0.0617,0.2287,0.0950,0.0740,0.1610,0.2226,0.2703,0.3365,0.4266,0.4144,0.5655,0.6921,0.8547,0.9234,0.9171,1.0000,0.9532,0.9101,0.8337,0.7053,0.6534,0.4483,0.2460,0.2020,0.1446,0.0994,0.1510,0.2392,0.4434,0.5023,0.4441,0.4571,0.3927,0.2900,0.3408,0.4990,0.3632,0.1387,0.1800,0.1299,0.0523,0.0817,0.0469,0.0114,0.0299,0.0244,0.0199,0.0257,0.0082,0.0151,0.0171,0.0146,0.0134,0.0056)


#changing a numpy data to a numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the np array as we are predicting only for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = model.predict(input_data_reshaped)
print(prediction)

if(prediction[0] == 'R'):
  print("The Object is a Rock")
else:
  print("The object is a Mine")
# Out:
# ['M']
# The object is a Mine

# %%
input_data2 =(0.0530,0.0885,0.1997,0.2604,0.3225,0.2247,0.0617,0.2287,0.0950,0.0740,0.1610,0.2226,0.2703,0.3365,0.4266,0.4144,0.5655,0.6921,0.8547,0.9234,0.9171,1.0000,0.9532,0.9101,0.8337,0.7053,0.6534,0.4483,0.2460,0.2020,0.1446,0.0994,0.1510,0.2392,0.4434,0.5023,0.4441,0.4571,0.3927,0.2900,0.3408,0.4990,0.3632,0.1387,0.1800,0.1299,0.0523,0.0817,0.0469,0.0114,0.0299,0.0244,0.0199,0.0257,0.0082,0.0151,0.0171,0.0146,0.0134,0.0056)


#changing a numpy data to a numpy array
input_data2_as_numpy_array = np.asarray(input_data2)

# reshape the np array as we are predicting only for one instance
input_data_reshaped2 = input_data2_as_numpy_array.reshape(1,-1)

prediction2 = model.predict(input_data_reshaped2)
print(prediction2)

if(prediction[0] == 'R'):
  print("The Object is a Rock")
else:
  print("The object is a Mine")
# Out:
# ['M']
# The object is a Mine
